# %% [markdown]
# <a href="https://colab.research.google.com/github/alfiyah0813/PhytonXIR3/blob/main/analisisdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data_nilai_siswa.csv')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-de51303e-f6f2-4e8d-8d37-3d24eedf36fe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de51303e-f6f2-4e8d-8d37-3d24eedf36fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nama    22 non-null     object
#  1   Matpel  22 non-null     object
#  2   Nilai   22 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 660.0+ bytes

# %%
data.head()
# Out:
#      Nama            Matpel  Nilai
# 0     Ade  Bahasa Indonesia     87
# 1    Aira  Bahasa Indonesia     88
# 2    Badi    Bahasa Inggris     78
# 3    Cyla    Bahasa Inggris     90
# 4  Khansa        Matematika     98

# %%
data.describe()
# Out:
#            Nilai
# count  22.000000
# mean   86.318182
# std     6.066193
# min    75.000000
# 25%    85.000000
# 50%    86.500000
# 75%    90.000000
# max    98.000000

# %%
print(data.columns)
print(data.head())
# Out:
# Index(['Nama', 'Matpel', 'Nilai'], dtype='object')
#      Nama            Matpel  Nilai
# 0     Ade  Bahasa Indonesia     87
# 1    Aira  Bahasa Indonesia     88
# 2    Badi    Bahasa Inggris     78
# 3    Cyla    Bahasa Inggris     90
# 4  Khansa        Matematika     98

# %%
print("Rata-rata:", data['Nilai'].mean())
print("Median:", data['Nilai'].median())
print("Modus:", data['Nilai'].mode()[0])
# Out:
# Rata-rata: 86.31818181818181
# Median: 86.5
# Modus: 85

# %%
matematika = data[data['Matpel'] == 'Matematika']
print(matematika)
# Out:
#      Nama      Matpel  Nilai
# 4  Khansa  Matematika     98
# 6     Dwi  Matematika     85

# %%
bindo = data[data['Matpel'] == 'Bahasa Indonesia']
print(bindo)
# Out:
#      Nama            Matpel  Nilai
# 0     Ade  Bahasa Indonesia     87
# 1    Aira  Bahasa Indonesia     88
# 11   Agus  Bahasa Indonesia     87
# 12  Gilam  Bahasa Indonesia     75

# %%
bing = data[data['Matpel'] == 'Bahasa Inggris']
print(bing)
# Out:
#    Nama          Matpel  Nilai
# 2  Badi  Bahasa Inggris     78
# 3  Cyla  Bahasa Inggris     90
# 5  Maya  Bahasa Inggris     85

# %%
fisika = data[data['Matpel'] == 'Fisika']
print(fisika)
# Out:
#       Nama  Matpel  Nilai
# 7     Raka  Fisika     95
# 8    Rasya  Fisika     90
# 10   Sania  Fisika     86
# 13    Rudi  Fisika     75
# 18  Evelyn  Fisika     90
# 19   Raina  Fisika     95
# 20     Ade  Fisika     90
# 21   Rasya  Fisika     85

# %%
produktif = data[data['Matpel'] == 'Produktif']
print(produktif)
# Out:
#       Nama     Matpel  Nilai
# 9     Mala  Produktif     80
# 14  Faizal  Produktif     80
# 15   Hanif  Produktif     90
# 16  Danish  Produktif     85
# 17  Darian  Produktif     85

# %%
data.groupby('Matpel')['Nilai'].agg(['max','min'])
# Out:
#                   max  min
# Matpel
# Bahasa Indonesia   88   75
# Bahasa Inggris     90   78
# Fisika             95   75
# Matematika         98   85
# Produktif          90   80

# %%
rata = data.groupby('Matpel')['Nilai'].mean()
rata.plot(kind='bar')
plt.title('Rata-Rata Nilai per Matpel')
plt.xlabel('Mata Pelajaran')
plt.ylabel('Nilai Rata-Rata')
plt.show()

# %%
sns.boxplot(x='Matpel', y='Nilai', data=data)
plt.title('Sebaran Nilai per Mata Pelajaran')
plt.show()

# %% [markdown]
# # **Analisis dan Pertanyaan**
#
# 1. Mapel mana yang memiliki rata-rata nilai tertinggi?
#
# *Jawaban* : Berdasarkan dengan perhitungan yang sudah ada, rata rata nilai tertinggi adalah Matematika, yaitu sekitar 91,5. Hal ini menunjukkan bahwa sebagian besar siswa memperoleh nilai tinggi di pelajaran Matematika.
#
# 2. Mapel mana yang memiliki nilai terendah?
#
# *Jawaban* : Mata Pelajaran dengan nilai terendah adalah Bahasa Inggris, dengan rata-rata sekitar 85-86 dan ada beberapa siswa yang mendapatkan nilai di bawah 80.
#
# 3. Bagaimana visualisasi membantu dalam memahami data?
#
# *Jawaban* : Visualisasi seperti grafik batang membantu melihat perbandingan nilai antar mata pelajaran dengan cepat.
# Kita bisa langsung tahu pelajaran mana yang nilai siswanya tinggi atau rendah tanpa harus membaca angka satu per satu.

# %% [markdown]
# # **Refleksi Siswa**
# 1. Apa hal baru yang kamu pelajari dari kegiatan analisis dan visualisasi data?
#
# *Jawaban* : Saya belajar cara menghitung ukuran statistik dasar menggunakan library Pandas serta membuat visualisasi data dengan Seaborn. Dari kegiatan ini, saya memahami cara menganalisis data seperti menghitung rata-rata, median, dan modus, serta menampilkan hasilnya dalam bentuk grafik secara otomatis.
#
#
# 2. Kesulitan apa yang kamu alami dalam membuat grafik?
#
# *Jawaban*: Awalnya saya kesulitan karena data CSV tidak terbaca dengan benar. Ternyata, penyebabnya adalah pemisah data yang masih menggunakan tanda titik koma (;) dan perlu diganti menjadi koma (,). Selain itu, saya juga sempat bingung menentukan jenis grafik yang paling sesuai agar hasil analisis mudah dipahami.
#
# 3. Menurut kamu AI apa membantu dalam analysis sebuah data?
#
# *Jawaban* : Menurut saya, AI sangat membantu dalam proses analisis data, terutama dalam menjelaskan kode, memperbaiki kesalahan, serta mempercepat pembuatan visualisasi. AI juga memberikan saran yang efisien dan membuat hasil analisis menjadi lebih menarik dan informatif.
